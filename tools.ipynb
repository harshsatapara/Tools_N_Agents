# %%
#https://docs.langchain.com/oss/python/integrations/tools
from langchain_community.tools import DuckDuckGoSearchRun

# %%
search_tools = DuckDuckGoSearchRun()
response = search_tools.invoke('Top news from india')
print(response)
# Out:
# 3 hours ago·India News · No Food, Phone Dead: How Lost Kerala Techie Survived 4 Days In Wild · 4-Year-Old Tied Up, Thrashed By Ex-Armyman For Plucking Guava · Mumbai ... 22 hours ago·... news from around India, the Indian Ocean Region, Indo Pacific and beyond ... In a major development in Indian Defence News and Latest Defence News, the Indian ... 1 day ago·Comments · News Ki Pathshala : Iran-US War के बीच भारत की ये तैयारी देख उड़े Asim Munir के होश! · UAE reached India to seek help, Iran disturbed America's sleep! · Aar Paar : ... 10 hours ago·Scroll.in is an independent website covering news, politics, sports, culture and everything in between. Get the latest news, reportage, analysis and ... 51 minutes ago·NEWS · Delhi Police Identify Suspects in Adarsh Nagar Arson Case · 'Trump is going by Hollywood script war' · Activist Anjali Damania Uses AI to Investigate ...

# %%
pip install langchain_experimental

# %%
from langchain_community.tools import ShellTool

# %%
shell_tool= ShellTool()
result = shell_tool.invoke('whoami')
print(result)
